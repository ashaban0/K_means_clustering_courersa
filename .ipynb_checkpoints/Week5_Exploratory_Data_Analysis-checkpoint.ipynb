# %% [markdown]
# # Week 5: Exploratory Data Analysis

# %% [markdown]
# ## Instructions

# %% [markdown]
# The goals of the exploratory data analysis are:
# * to better understand your data,
# * to evaluate if the given dataset is suitable for the K-means clustering task.

# %% [markdown]
# You need to:
# 1. Load the given Banknote authentication dataset.
# 2. Calculate statistical measures, e.g. mean and standard deviation.
# 3. Visualize your data as you consider fit.
# 4. Evaluate if the given dataset is suitable for the K-means clustering task.
# 5. Write a short description of the data set and your evluation of its suitability for the K-means clustering task.

# %% [markdown]
# ##  Grading Criteria

# %% [markdown]
# Once you have completed all five steps, you should submit a brief description of the dataset and your evaluation of its suitability for K-Means clustering.
#
# This description and evaluation will be assessed by your peers, who will check that is has the following characteristics:
# * The description is informative and relies on statistical measures.
# * The evaluation of the suitability is based on the characteristics of the dataset.

# %% [markdown]
# ## Code and analysis

# %% [markdown]
# ### Loading the important libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %% [markdown]
# ### 1) Load the CSV file

# %%
df = pd.read_csv('BankNote_Authentication.csv')
var = np.array(df['variance'])
skew = np.array(df['skewness'])
curt = np.array(df['curtosis'])
entr = np.array(df['entropy'])
clas = np.array(df['class'])

df1 = df[ df['class'] > 0 ]
df0 = df[ df['class'] < 1]

v_list = [var, skew, curt, entr]
v_names = ["Variance", "Skewness", "Curtosis", "Entropy"]
df
# Out:
#       variance  skewness  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %% [markdown]
# ### 2) Calculate statistical measures, e.g. mean and standard devaition

# %%
for i in range(len(v_list)):
    m = np.mean(v_list[i])
    std = np.std(v_list[i])
    print(v_names[i]," Mean: ", m, ", standard deviation: ", std)
# Out:
# Variance  Mean:  0.4337352570699707 , standard deviation:  2.841726405239481
# Skewness  Mean:  1.9223531206393585 , standard deviation:  5.866907488387089
# Curtosis  Mean:  1.3976271172667638 , standard deviation:  4.308459093119795
# Entropy  Mean:  -1.1916565200437317 , standard deviation:  2.100247322449037

# %%
mean_v_0 = np.mean(df0.variance) 
mean_v_1 = np.mean(df1.variance)

mean_sk_0 = np.mean(df0.skewness)
mean_sk_1 = np.mean(df1.skewness)

std_v_0 = np.std(df0.variance)
std_v_1 = np.std(df1.variance)

std_sk_0 = np.std(df0.skewness)
std_sk_1 = np.std(df1.skewness)

# %% [markdown]
# ### 3) Visualize your data as you consider fit

# %%
mark = 10
#### Skewness versus variance of wavelet
plt.close()
fig = plt.figure(1, figsize=(6,6), dpi=300)
ax1 = fig.add_subplot(111)
ax1.scatter(df0.variance, df0.skewness, s=10, color='b', label='0')
ax1.scatter(df1.variance, df1.skewness, s=10, color='orange', label='1')

ax1.plot( mean_v_0, mean_sk_0, 'kx', markersize=mark)
ax1.plot( mean_v_1, mean_sk_1, 's', c='k', markersize=mark)

ax1.text(mean_v_0+0.3, mean_sk_0, "Mean 0", fontsize='15', color='m')
ax1.text(mean_v_1+0.3, mean_sk_1, "Mean 1", fontsize='15', color='m')


e0 = Ellipse( (mean_v_0, mean_sk_0), width=3*std_v_0, height=3*std_sk_0, alpha=0.2, color='b' )
e1 = Ellipse( (mean_v_1, mean_sk_1), width=3*std_v_1, height=3*std_sk_1, alpha=0.2, color='orange' )

ax1.set_xlabel("V1 Variance of Wavelet")
ax1.set_ylabel("V2 Skewness of Wavelet")

ax1.add_patch(e0)
ax1.add_patch(e1)
ax1.legend(loc=0)


fig.tight_layout()
plt.show()

fig.savefig('Skewness_Vs_Variance_Wavelet_BankNote.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# #### Figure caption
# Skewness of the wavelet on the y-axis versus the variance of the wavelet on the x-axis. Blue datapoints represent the counterfeit banknotes. Orange datapoints represent the real banknotes. The blue ellipse is centered on the mean of the counterfeit with width and height equal to 2 standard deviations of the variance and skewness of the counterfeit. The orange ellipse is centered on the mean of the real banknotes with width and height equal to 2 standard deviations of the variance and skewness of the real banknotes.

# %% [markdown]
# ### 4) Evaluate if the given dataset is suitable for the K-means clustering task

# %% [markdown]
# It seems that K-means clustering will work in classification of this task

# %% [markdown]
# ### 5) Write a short description of the data set and your evluation of its suitability for the K-means clustering task.

# %% [markdown]
# The K-means clustering can work on the banknote dataset to classify the data to either original or counterfeit banknote. From the visualization of the skewness versus variance of the wavelet analysis for both real and counterfeit banknotes, that there are two clusters of datapoints. Most of these data points are contained in the faint ellipses in the Figure. These ellipses are centered on the means of skewness and variances for real and counterfeit, with width and heights as 2 standard deviations. The significance of the 2 standard deviations is that they contain 95% of the data.
